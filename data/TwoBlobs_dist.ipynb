# %%
# %load_ext autoreload
# %autoreload 2

import os
import sys

# %store -r DISCO_ROOT_FOLDER
if "DISCO_ROOT_FOLDER" in globals():
    os.chdir(DISCO_ROOT_FOLDER)
    sys.path.append(DISCO_ROOT_FOLDER)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import numpy as np
from sklearn.datasets import make_blobs

def make_blobs_dist(n_samples, dist=0, seed=0):
    np.random.seed(seed)
    X, l = make_blobs(n_samples, 2, centers=np.array([[0-dist, 0], [0+dist, 0]]), cluster_std=[1, 1])
    return X, l


np.random.seed(0)
random_seeds = np.random.choice(1_000_000, replace=False, size=10)
dists = np.arange(0, 15.1, 0.5)
blobs_datasets = [[make_blobs_dist(500, dist=dist, seed=seed) for seed in random_seeds] for dist in dists]

# %%
import matplotlib.pyplot as plt


X, l = make_blobs_dist(500, 0, 0)

plt.figure(figsize=(5, 5))
color = plt.cm.tab20(np.linspace(0, 1, len(set(l)) + 1))
for c_id in np.sort(list(set(l))):
    plt.scatter(
        X[:, 0][l == c_id], X[:, 1][l == c_id], s=5, color=color[int(c_id) + 1], label=int(c_id)
    )
legend = plt.legend(
    loc="center left",
    bbox_to_anchor=(1, 0.5),
)
ax = plt.gca()
plt.ylim(-10, 10)
plt.xlim(-10, 10)
ax.set_aspect("equal", adjustable="datalim")

# %%
import matplotlib.pyplot as plt
from data._util_plots import plot_datasets

fig = plot_datasets(blobs_datasets, dists, rows=7, cols=5, figsize=1.5)

axes = fig.get_axes()
for ax in axes:
    ax.set_ylim(-20, 20)
    ax.set_xlim(-20, 20)
    ax.set_aspect("equal", adjustable="datalim")

plt.savefig("imgs/TwoBlobs_dist_data.png")

# %%
from data._util_experiments import cache, calc_eval_measures_for_multiple_datasets
from data._metrics import create_and_filter_df


eval_results = cache("TwoBlobs_dist", calc_eval_measures_for_multiple_datasets, [blobs_datasets])

df = create_and_filter_df(eval_results)

# %%
from data._util_plots import plot_lineplot

eps = 0.2
ymin, ymax = dists[0] - eps, dists[-1] + eps
df = df.rename(columns={"dataset": "dist"})

plot_lineplot(df, "dist", "value", "measure", x_range=(ymin, ymax), y_range=(None, None))
plt.savefig("imgs/TwoBlobs_dist.png")
