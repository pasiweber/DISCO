# %%
DISCO_ROOT_FOLDER = "/export/share/pascalw777dm/DISCO/"
# %store DISCO_ROOT_FOLDER
# Out:
# Stored 'DISCO_ROOT_FOLDER' (str)

# %%
# %store
# Out:
# Stored variables and their in-db values:
# DISCO_ROOT_FOLDER             -> '/export/share/pascalw777dm/DISCO/'

# %%
import os
import sys

# %store -r DISCO_ROOT_FOLDER
if "DISCO_ROOT_FOLDER" in globals():
    os.chdir(DISCO_ROOT_FOLDER)
    sys.path.append(DISCO_ROOT_FOLDER)

# %%
# Clear Cache
# %store -r DISCO_ROOT_FOLDER
os.chdir(DISCO_ROOT_FOLDER)
# !rm ./.cache/*
# Out:
# /export/share/pascalw777dm/DISCO
