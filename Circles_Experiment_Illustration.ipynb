# %% [markdown]
# # Results

# %% [markdown]
# ![Jitter Example](./motivation_jitterv2.png)

# %% [markdown]
# - DISCO: 0.39
# - DBCV: 0.68

# %% [markdown]
# ![Pure Noise Example](./motivation_pureNoisev2.png)

# %% [markdown]
# - DISCO: 0.89
# - DBCV: 0.6
