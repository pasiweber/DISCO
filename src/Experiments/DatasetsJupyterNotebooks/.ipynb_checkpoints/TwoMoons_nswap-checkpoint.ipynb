# %%
# %load_ext autoreload
# %autoreload 2

import os
import sys

# %store -r DISCO_ROOT_FOLDER
if "DISCO_ROOT_FOLDER" in globals():
    os.chdir(DISCO_ROOT_FOLDER)
    sys.path.append(DISCO_ROOT_FOLDER)
# Out:
# /Users/lenakrieger/PycharmProjects/DISCO/.venv/lib/python3.12/site-packages/IPython/extensions/storemagic.py:148: UserWarning: This is now an optional IPython functionality, using autorestore/DISCO_ROOT_FOLDER requires you to install the `pickleshare` library.
#   obj = db["autorestore/" + arg]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 9
#       7 get_ipython().run_line_magic('store', '-r DISCO_ROOT_FOLDER')
#       8 if "DISCO_ROOT_FOLDER" in globals():
# ----> 9     os.chdir(DISCO_ROOT_FOLDER)
#      10     sys.path.append(DISCO_ROOT_FOLDER)
#
# TypeError: chdir: path should be string, bytes, os.PathLike or integer, not NoneType

# %%
import numpy as np
from sklearn.datasets import make_moons
from src.utils.data import add_noise

def make_moons_random_assignment(n_samples, n_swap=0, seed=0):
    np.random.seed(seed)
    X, l = make_moons(n_samples=n_samples, random_state=seed, noise=0.0)
    # X, l = add_noise(X, l, 20, 0.1)
    class0 = np.where(l == 0)[0]
    class1 = np.where(l == 1)[0]
    choice_class0 = np.random.choice(len(class0), replace=False, size=n_samples // 100 * n_swap)
    choice_class1 = np.random.choice(len(class1), replace=False, size=n_samples // 100 * n_swap)
    l[class0[choice_class0]] = 1
    l[class1[choice_class1]] = 0
    return X, l


np.random.seed(0)
random_seeds = np.random.choice(1_000_000, replace=False, size=10)
n_swaps = range(0, 26)
twoMoons_datasets = [
    [make_moons_random_assignment(500, n_swap=n_swap, seed=seed) for seed in random_seeds]
    for n_swap in n_swaps
]

# %%
import matplotlib.pyplot as plt
from src.utils.plots import plot_datasets

plot_datasets(twoMoons_datasets[1:], n_swaps[1:], rows=5, cols=5, figsize=1.6)
plt.savefig("imgs/TwoMoons_nswap_data.png")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 5
#       2 from src.utils.plots import plot_datasets
#       4 plot_datasets(twoMoons_datasets[1:], n_swaps[1:], rows=5, cols=5, figsize=1.6)
# ----> 5 plt.savefig("imgs/TwoMoons_nswap_data.png")
#
# File ~/PycharmProjects/DISCO/.venv/lib/python3.12/site-packages/matplotlib/pyplot.py:1223, in savefig(*args, **kwargs)
#    1220 fig = gcf()
#    1221 # savefig default implementation has no return, so mypy is unhappy
#    1222 # presumably this is here because subclasses can return?
# -> 1223 res = fig.savefig(*args, **kwargs)  # type: ignore[func-returns-value]
#    1224 fig.canvas.draw_idle()  # Need this if 'transparent=True', to reset colors.
#    1225 return res
#
# File ~/PycharmProjects/DISCO/.venv/lib/python3.12/site-packages/matplotlib/figure.py:3388, in Figure.savefig(self, fname, transparent, **kwargs)
#    3386     for ax in self.axes:
#    3387         _recursively_make_axes_transparent(stack, ax)
# -> 3388 self.canvas.print_figure(fname, **kwargs)
#
# File ~/PycharmProjects/DISCO/.venv/lib/python3.12/site-packages/matplotlib/backend_bases.py:2218, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2214 try:
#    2215     # _get_renderer may change the figure dpi (as vector formats
#    2216     # force the figure dpi to 72), so we need to set it again here.
#    2217     with cbook._setattr_cm(self.figure, dpi=dpi):
# -> 2218         result = print_method(
#    2219             filename,
#    2220             facecolor=facecolor,
#    2221             edgecolor=edgecolor,
#    2222             orientation=orientation,
#    2223             bbox_inches_restore=_bbox_inches_restore,
#    2224             **kwargs)
#    2225 finally:
#    2226     if bbox_inches and restore_bbox:
#
# File ~/PycharmProjects/DISCO/.venv/lib/python3.12/site-packages/matplotlib/backend_bases.py:2068, in FigureCanvasBase._switch_canvas_and_return_print_method.<locals>.<lambda>(*args, **kwargs)
#    2064     optional_kws = {  # Passed by print_figure for other renderers.
#    2065         "dpi", "facecolor", "edgecolor", "orientation",
#    2066         "bbox_inches_restore"}
#    2067     skip = optional_kws - {*inspect.signature(meth).parameters}
# -> 2068     print_method = functools.wraps(meth)(lambda *args, **kwargs: meth(
#    2069         *args, **{k: v for k, v in kwargs.items() if k not in skip}))
#    2070 else:  # Let third-parties do as they see fit.
#    2071     print_method = meth
#
# File ~/PycharmProjects/DISCO/.venv/lib/python3.12/site-packages/matplotlib/backends/backend_agg.py:496, in FigureCanvasAgg.print_png(self, filename_or_obj, metadata, pil_kwargs)
#     449 def print_png(self, filename_or_obj, *, metadata=None, pil_kwargs=None):
#     450     """
#     451     Write the figure to a PNG file.
#     452
#    (...)
#     494         *metadata*, including the default 'Software' key.
#     495     """
# --> 496     self._print_pil(filename_or_obj, "png", pil_kwargs, metadata)
#
# File ~/PycharmProjects/DISCO/.venv/lib/python3.12/site-packages/matplotlib/backends/backend_agg.py:445, in FigureCanvasAgg._print_pil(self, filename_or_obj, fmt, pil_kwargs, metadata)
#     440 """
#     441 Draw the canvas, then save it using `.image.imsave` (to which
#     442 *pil_kwargs* and *metadata* are forwarded).
#     443 """
#     444 FigureCanvasAgg.draw(self)
# --> 445 mpl.image.imsave(
#     446     filename_or_obj, self.buffer_rgba(), format=fmt, origin="upper",
#     447     dpi=self.figure.dpi, metadata=metadata, pil_kwargs=pil_kwargs)
#
# File ~/PycharmProjects/DISCO/.venv/lib/python3.12/site-packages/matplotlib/image.py:1676, in imsave(fname, arr, vmin, vmax, cmap, format, origin, dpi, metadata, pil_kwargs)
#    1674 pil_kwargs.setdefault("format", format)
#    1675 pil_kwargs.setdefault("dpi", (dpi, dpi))
# -> 1676 image.save(fname, **pil_kwargs)
#
# File ~/PycharmProjects/DISCO/.venv/lib/python3.12/site-packages/PIL/Image.py:2563, in Image.save(self, fp, format, **params)
#    2561         fp = builtins.open(filename, "r+b")
#    2562     else:
# -> 2563         fp = builtins.open(filename, "w+b")
#    2564 else:
#    2565     fp = cast(IO[bytes], fp)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/lenakrieger/PycharmProjects/DISCO/src/Experiments/DatasetsJupyterNotebooks/imgs/TwoMoons_nswap_data.png'

# %%
from src.utils.experiments import cache, calc_eval_measures_for_multiple_datasets
from src.utils.metrics import create_and_filter_df


eval_results = cache(
    "TwoMoons_nswap",
    calc_eval_measures_for_multiple_datasets,
    [twoMoons_datasets, n_swaps],
    recalc=True,
)

df = create_and_filter_df(eval_results)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[8], line 5
#       1 from src.utils.experiments import cache, calc_eval_measures_for_multiple_datasets
#       2 from src.utils.metrics import create_and_filter_df
# ----> 5 eval_results = cache(
#       6     "TwoMoons_nswap",
#       7     calc_eval_measures_for_multiple_datasets,
#       8     [twoMoons_datasets, n_swaps],
#       9     recalc=True,
#      10 )
#      12 df = create_and_filter_df(eval_results)
#
# File ~/PycharmProjects/DISCO/src/utils/experiments.py:27, in cache(filename, func, args, kwargs, recalc)
#      25         return pickle.load(handle)
#      26 else:
# ---> 27     result = func(*args, **kwargs)
#      28     with open(cache_path, "wb") as handle:
#      29         pickle.dump(result, handle, protocol=pickle.HIGHEST_PROTOCOL)
#
# File ~/PycharmProjects/DISCO/src/utils/experiments.py:111, in calc_eval_measures_for_multiple_datasets(data, param_values, metrics, n_jobs, task_timeout)
#     102 def calc_eval_measures_for_multiple_datasets(
#     103     data, param_values, metrics=METRICS, n_jobs=32, task_timeout=None
#     104 ):
#     105     """Calculates all evaluation measures for all datasets in data.
#     106
#     107     Args:
#     108         data: 2d matrix of type [datasets x runs]
#     109     """
# --> 111     pool = WorkerPool(n_jobs=n_jobs, use_dill=True)
#     112     async_results = {}
#     114     for param_value in range(len(param_values)):
#
# File ~/PycharmProjects/DISCO/.venv/lib/python3.12/site-packages/mpire/pool.py:87, in WorkerPool.__init__(self, n_jobs, daemon, cpu_ids, shared_objects, pass_worker_id, use_worker_state, start_method, keep_alive, use_dill, enable_insights, order_tasks)
#      84 self.map_params = None  # type: Optional[WorkerMapParams]
#      86 # Worker factory
# ---> 87 self.Worker = worker_factory(start_method, use_dill)
#      89 # Multiprocessing context
#      90 if start_method == 'threading':
#
# File ~/PycharmProjects/DISCO/.venv/lib/python3.12/site-packages/mpire/worker.py:708, in worker_factory(start_method, use_dill)
#     706 elif use_dill:
#     707     if not DILL_INSTALLED:
# --> 708         raise ImportError("Can't use dill as the dependency \"multiprocess\" is not installed. Use `pip install "
#     709                           "mpire[dill]` to install the required dependency")
#     710     elif start_method == 'fork':
#     711         if not FORK_AVAILABLE:
#
# ImportError: Can't use dill as the dependency "multiprocess" is not installed. Use `pip install mpire[dill]` to install the required dependency

# %%
from src.utils.plots import plot_lineplot

eps = 0.1
x_range = n_swaps[0] - eps, n_swaps[-1] + eps
df = df.rename(columns={"dataset": "n_swaps"})

plot_lineplot(df, "n_swaps", "value", "measure", x_range=x_range, y_range=(None, None))
plt.savefig("imgs/TwoMoons_nswap.png")
