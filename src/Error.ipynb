# %%
# %load_ext autoreload
# %autoreload 2

import os
import sys

# %store -r DISCO_ROOT_FOLDER
if "DISCO_ROOT_FOLDER" in globals():
    os.chdir(DISCO_ROOT_FOLDER)
    sys.path.append(DISCO_ROOT_FOLDER)

# %%
from datasets.density_datasets import Datasets as DensityDatasets
from src.Evaluation import dbcv_score

X, l = DensityDatasets.chainlink.standardized_data_cached
dbcv_score(X, l)
# Out:
# /export/share/pascalw777dm/DISCO/src/Evaluation/DBCV/dbcv.py:459: RuntimeWarning: invalid value encountered in scalar divide
#   cluster_validity_indices[i] = numerator / max(min_density_sep, density_sparseness[i])
# nan

# %%
from datasets.density_datasets import Datasets as DensityDatasets
from src.Evaluation import cdbw_score

X, l = DensityDatasets.chainlink.standardized_data_cached
cdbw_score(X, l)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 5
#       2 from src.Evaluation import cdbw_score
#       4 X, l = DensityDatasets.chainlink.standardized_data_cached
# ----> 5 cdbw_score(X, l)
#
# File /export/share/pascalw777dm/DISCO/src/Evaluation/CDBW/cdbw.py:588, in cdbw_score(X, labels, metric, alg_noise, intra_dens_inf, s, multipliers)
#     586 labels = np.asarray(labels)
#     587 distvec = gen_dist_func(metric)
# --> 588 n_clusters, stdev, dimension, n_points_in_cl, n_max, coord_in_cl, labels_in_cl = prep(X, labels)
#     589 mean_arr, n_rep, n_rep_max, rep_in_cl = rep(n_clusters, dimension, n_points_in_cl, coord_in_cl, labels_in_cl)
#     590 middle_point, dist_min, n_cl_rep = closest_rep(X, n_clusters, rep_in_cl, n_rep, metric, distvec)
#
# File /export/share/pascalw777dm/DISCO/src/Evaluation/CDBW/cdbw.py:167, in prep(X, labels)
#     165 std1_cl = np.zeros(shape=n_clusters, dtype=float)
#     166 for i in range(n_clusters):
# --> 167     n_points_in_cl[i] = Counter(labels).get(i)
#     168     stdv1_cl[i] = np.std(X[labels == i], axis=0)
#     169     std1_cl[i] = np.dot(stdv1_cl[i].T, stdv1_cl[i])
#
# TypeError: int() argument must be a string, a bytes-like object or a real number, not 'NoneType'
